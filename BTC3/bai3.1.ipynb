# %%
#in phiên bản
import numpy as np

print("Current NumPy version:", np.__version__)
# Out:
# Current NumPy version: 2.3.4

# %%
# hiển thị cấu hình
np.show_config()
# Out:
# Build Dependencies:
#   blas:
#     detection method: pkgconfig
#     found: true
#     include directory: /private/var/folders/vk/nx37ffx50hv5djclhltc26vw0000gn/T/cibw-run-gzxqlw7o/cp313-macosx_x86_64/build/venv/lib/python3.13/site-packages/scipy_openblas64/include
#     lib directory: /private/var/folders/vk/nx37ffx50hv5djclhltc26vw0000gn/T/cibw-run-gzxqlw7o/cp313-macosx_x86_64/build/venv/lib/python3.13/site-packages/scipy_openblas64/lib
#     name: scipy-openblas
#     openblas configuration: OpenBLAS 0.3.30  USE64BITINT DYNAMIC_ARCH NO_AFFINITY
#       Sandybridge MAX_THREADS=64
#     pc file directory: /Users/runner/work/numpy-release/numpy-release/.openblas
#     version: 0.3.30
#   lapack:
#     detection method: pkgconfig
#     found: true
#     include directory: /private/var/folders/vk/nx37ffx50hv5djclhltc26vw0000gn/T/cibw-run-gzxqlw7o/cp313-macosx_x86_64/build/venv/lib/python3.13/site-packages/scipy_openblas64/include
# ...

# %%
# cấu hình chi tiết
import numpy.__config__ as np_config

np_config.show()
# Out:
# Build Dependencies:
#   blas:
#     detection method: pkgconfig
#     found: true
#     include directory: /private/var/folders/vk/nx37ffx50hv5djclhltc26vw0000gn/T/cibw-run-gzxqlw7o/cp313-macosx_x86_64/build/venv/lib/python3.13/site-packages/scipy_openblas64/include
#     lib directory: /private/var/folders/vk/nx37ffx50hv5djclhltc26vw0000gn/T/cibw-run-gzxqlw7o/cp313-macosx_x86_64/build/venv/lib/python3.13/site-packages/scipy_openblas64/lib
#     name: scipy-openblas
#     openblas configuration: OpenBLAS 0.3.30  USE64BITINT DYNAMIC_ARCH NO_AFFINITY
#       Sandybridge MAX_THREADS=64
#     pc file directory: /Users/runner/work/numpy-release/numpy-release/.openblas
#     version: 0.3.30
#   lapack:
#     detection method: pkgconfig
#     found: true
#     include directory: /private/var/folders/vk/nx37ffx50hv5djclhltc26vw0000gn/T/cibw-run-gzxqlw7o/cp313-macosx_x86_64/build/venv/lib/python3.13/site-packages/scipy_openblas64/include
# ...
