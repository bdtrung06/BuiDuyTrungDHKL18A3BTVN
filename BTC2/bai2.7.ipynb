# %%
from xml.dom import minidom

# đọc file XML
doc = minidom.parse("xml/sample.xml")

# lấy danh sách tất cả <staff>
staffs = doc.getElementsByTagName("staff")

print("Danh sách nhân viên theo id:")
for staff in staffs:
    staff_id = staff.getAttribute("id")
    name = staff.getElementsByTagName("name")[0].firstChild.nodeValue
    salary = staff.getElementsByTagName("salary")[0].firstChild.nodeValue
    print(f"ID: {staff_id}, Name: {name}, Salary: {salary}")
# Out:
# Danh sách nhân viên theo id:
# ID: 1, Name: Amar Pandey, Salary: 8.5 LPA
# ID: 2, Name: Akbhar Khan, Salary: 6.5 LPA
# ID: 3, Name: Anthony Walter, Salary: 3.2 LPA
